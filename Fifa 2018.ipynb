# %%
import pandas as pd
# %matplotlib inline
import seaborn as sns

# %%
data_fifa = pd.read_csv('fifa-2018-match-statistics\\FIFA 2018 Statistics.csv')

# %%
data_fifa.head()
# Out:
#          Date          Team      Opponent  Goal Scored  Ball Possession %  \
# 0  14-06-2018        Russia  Saudi Arabia            5                 40
# 1  14-06-2018  Saudi Arabia        Russia            0                 60
# 2  15-06-2018         Egypt       Uruguay            0                 43
# 3  15-06-2018       Uruguay         Egypt            1                 57
# 4  15-06-2018       Morocco          Iran            0                 64
#
#    Attempts  On-Target  Off-Target  Blocked  Corners      ...        \
# 0        13          7           3        3        6      ...
# 1         6          0           3        3        2      ...
# 2         8          3           3        2        0      ...
# 3        14          4           6        4        5      ...
# 4        13          3           6        4        5      ...
#
#    Yellow Card  Yellow & Red  Red  Man of the Match  1st Goal        Round  \
# ...

# %%
data_fifa.shape
# Out:
# (128, 27)

# %% [markdown]
# ## Visualize some results per team

# %% [markdown]
# #### visualize the goals marked per country

# %%
import matplotlib.pyplot as plt
groupedSortedData = data_fifa.groupby('Team')['Goal Scored'].mean().reset_index().sort_values(by='Goal Scored', ascending=False)
plt.figure(figsize = (17, 10), facecolor = None)
sns.set(font_scale=1.5)
plot1 = sns.barplot(x='Team', y='Goal Scored', data=groupedSortedData)
plot1.set_xticklabels(groupedSortedData['Team'], rotation=90, ha="center")
# Out:
# [Text(0,0,'Belgium'),
#  Text(0,0,'Russia'),
#  Text(0,0,'Croatia'),
#  Text(0,0,'France'),
#  Text(0,0,'Spain'),
#  Text(0,0,'England'),
#  Text(0,0,'Tunisia'),
#  Text(0,0,'Brazil'),
#  Text(0,0,'Argentina'),
#  Text(0,0,'Japan'),
#  Text(0,0,'Colombia'),
#  Text(0,0,'Portugal'),
#  Text(0,0,'Uruguay'),
#  Text(0,0,'Senegal'),
#  Text(0,0,'Switzerland'),
#  Text(0,0,'Sweden'),
#  Text(0,0,'Korea Republic'),
#  Text(0,0,'Nigeria'),
#  Text(0,0,'Mexico'),
#  Text(0,0,'Denmark'),
#  Text(0,0,'Saudi Arabia'),
#  Text(0,0,'Costa Rica'),
#  Text(0,0,'Serbia'),
#  Text(0,0,'Iran'),
#  Text(0,0,'Egypt'),
#  Text(0,0,'Iceland'),
#  Text(0,0,'Poland'),
#  Text(0,0,'Peru'),
#  Text(0,0,'Panama'),
#  Text(0,0,'Morocco'),
#  Text(0,0,'Australia'),
#  Text(0,0,'Germany')]

# %% [markdown]
# #### visualize the goals received by country

# %%
import matplotlib.pyplot as plt
groupedReceived = data_fifa.groupby('Opponent')['Goal Scored'].mean().reset_index().sort_values(by='Goal Scored', ascending=False)
plt.figure(figsize = (17, 10), facecolor = None)
sns.set(font_scale=1.5)
plot1 = sns.barplot(x='Opponent', y='Goal Scored', data=groupedReceived)
plot1.set_xticklabels(groupedReceived['Opponent'], rotation=90, ha="center")
# Out:
# [Text(0,0,'Panama'),
#  Text(0,0,'Tunisia'),
#  Text(0,0,'Saudi Arabia'),
#  Text(0,0,'Argentina'),
#  Text(0,0,'Egypt'),
#  Text(0,0,'Japan'),
#  Text(0,0,'Iceland'),
#  Text(0,0,'Costa Rica'),
#  Text(0,0,'Poland'),
#  Text(0,0,'Australia'),
#  Text(0,0,'Spain'),
#  Text(0,0,'Portugal'),
#  Text(0,0,'Mexico'),
#  Text(0,0,'Russia'),
#  Text(0,0,'Morocco'),
#  Text(0,0,'Nigeria'),
#  Text(0,0,'Germany'),
#  Text(0,0,'Senegal'),
#  Text(0,0,'Serbia'),
#  Text(0,0,'Croatia'),
#  Text(0,0,'Switzerland'),
#  Text(0,0,'England'),
#  Text(0,0,'Korea Republic'),
#  Text(0,0,'France'),
#  Text(0,0,'Belgium'),
#  Text(0,0,'Sweden'),
#  Text(0,0,'Colombia'),
#  Text(0,0,'Iran'),
#  Text(0,0,'Peru'),
#  Text(0,0,'Brazil'),
#  Text(0,0,'Uruguay'),
#  Text(0,0,'Denmark')]

# %% [markdown]
# #### The number of blocked balls

# %%
import matplotlib.pyplot as plt
groupedBlocked = data_fifa.groupby('Opponent')['Blocked'].mean().reset_index().sort_values(by='Blocked', ascending=False)
plt.figure(figsize = (17, 10), facecolor = None)
sns.set(font_scale=1.5)
plot1 = sns.barplot(x='Opponent', y='Blocked', data=groupedBlocked)
plot1.set_xticklabels(groupedBlocked['Opponent'], rotation=90, ha="center")
# Out:
# [Text(0,0,'Sweden'),
#  Text(0,0,'Iceland'),
#  Text(0,0,'Korea Republic'),
#  Text(0,0,'Mexico'),
#  Text(0,0,'Iran'),
#  Text(0,0,'Russia'),
#  Text(0,0,'Serbia'),
#  Text(0,0,'Belgium'),
#  Text(0,0,'Denmark'),
#  Text(0,0,'Egypt'),
#  Text(0,0,'Japan'),
#  Text(0,0,'Costa Rica'),
#  Text(0,0,'Switzerland'),
#  Text(0,0,'Poland'),
#  Text(0,0,'Croatia'),
#  Text(0,0,'England'),
#  Text(0,0,'Colombia'),
#  Text(0,0,'Peru'),
#  Text(0,0,'Uruguay'),
#  Text(0,0,'Brazil'),
#  Text(0,0,'Panama'),
#  Text(0,0,'Saudi Arabia'),
#  Text(0,0,'Tunisia'),
#  Text(0,0,'France'),
#  Text(0,0,'Morocco'),
#  Text(0,0,'Argentina'),
#  Text(0,0,'Portugal'),
#  Text(0,0,'Spain'),
#  Text(0,0,'Nigeria'),
#  Text(0,0,'Senegal'),
#  Text(0,0,'Germany'),
#  Text(0,0,'Australia')]

# %%
data_fifa.describe()
# Out:
#        Goal Scored  Ball Possession %    Attempts   On-Target  Off-Target  \
# count   128.000000         128.000000  128.000000  128.000000  128.000000
# mean      1.320312          49.992188   12.593750    3.914062    5.273438
# std       1.156519          10.444074    5.245827    2.234403    2.409675
# min       0.000000          25.000000    3.000000    0.000000    1.000000
# 25%       0.000000          42.000000    9.000000    2.000000    4.000000
# 50%       1.000000          50.000000   12.000000    3.500000    5.000000
# 75%       2.000000          58.000000   15.000000    5.000000    7.000000
# max       6.000000          75.000000   26.000000   12.000000   11.000000
#
#           Blocked     Corners    Offsides  Free Kicks       Saves  \
# count  128.000000  128.000000  128.000000  128.000000  128.000000
# mean     3.359375    4.718750    1.343750   14.890625    2.726562
# std      2.403195    2.446072    1.193404    4.724262    2.049447
# ...

# %%
data_fifa.groupby('Man of the Match').mean()
# Out:
#                   Goal Scored  Ball Possession %   Attempts  On-Target  \
# Man of the Match
# No                   0.734375          48.875000  11.796875   3.328125
# Yes                  1.906250          51.109375  13.390625   4.500000
#
#                   Off-Target  Blocked   Corners  Offsides  Free Kicks  \
# Man of the Match
# No                  4.937500  3.43750  4.359375    1.3125    14.37500
# Yes                 5.609375  3.28125  5.078125    1.3750    15.40625
#
#                      Saves      ...            Passes  Distance Covered (Kms)  \
# Man of the Match                ...
# No                2.750000      ...        448.843750              106.359375
# Yes               2.703125      ...        476.453125              106.968750
#
#                   Fouls Committed  Yellow Card  Yellow & Red      Red  \
# Man of the Match
# No                       14.09375     1.859375      0.015625  0.03125
# ...

# %%
#visualizes the different attributes based on the fact that this team had the man of the match or not
import seaborn as sns
sns.countplot('Goal Scored', data=data_fifa, hue='Man of the Match', palette='coolwarm')

# %%
sns.boxplot(x='Man of the Match',y='Ball Possession %', data=data_fifa, palette='coolwarm')

# %%
from scipy import stats
import numpy as np

plt.figure(figsize = (14, 8), facecolor = None)
mplot = sns.countplot('Attempts', data=data_fifa, hue='Man of the Match', palette='coolwarm')

#fit beta distribution
xmin, xmax = min(data_fifa['Attempts']), max(data_fifa['Attempts'])  
lnspc = np.linspace(xmin, xmax, len(data_fifa[data_fifa['Man of the Match']=='Yes']['Attempts']))
ab,bb,cb = stats.gamma.fit(data_fifa[data_fifa['Man of the Match']=='Yes']['Attempts'])  
pdf_beta = 50* stats.gamma.pdf(lnspc, ab, bb,cb)  
plt.plot(lnspc, pdf_beta, label="Beta")

# %%
plt.hist(data_fifa[data_fifa['Man of the Match']=='Yes']['Attempts'],bins=15, normed=True)
#fit beta distribution
xmin, xmax = min(data_fifa['Attempts']), max(data_fifa['Attempts'])  
lnspc = np.linspace(xmin, xmax, len(data_fifa[data_fifa['Man of the Match']=='Yes']['Attempts']))
m, s = stats.norm.fit(data_fifa[data_fifa['Man of the Match']=='Yes']['Attempts'])  
pdf_norm = stats.norm.pdf(lnspc, m, s)  
plt.plot(lnspc, pdf_norm, label="Norm")

# %%
data_fifa[data_fifa['Man of the Match']=='Yes']['Attempts'].mean()
# Out:
# 13.390625

# %%
sns.boxplot(x='Man of the Match',y='Attempts', data=data_fifa, palette='coolwarm')

# %% [markdown]
# #### Now let's visualize the whole data using parallel coordinates

# %%
data_fifa.head()
# Out:
#          Date          Team      Opponent  Goal Scored  Ball Possession %  \
# 0  14-06-2018        Russia  Saudi Arabia            5                 40
# 1  14-06-2018  Saudi Arabia        Russia            0                 60
# 2  15-06-2018         Egypt       Uruguay            0                 43
# 3  15-06-2018       Uruguay         Egypt            1                 57
# 4  15-06-2018       Morocco          Iran            0                 64
#
#    Attempts  On-Target  Off-Target  Blocked  Corners      ...        \
# 0        13          7           3        3        6      ...
# 1         6          0           3        3        2      ...
# 2         8          3           3        2        0      ...
# 3        14          4           6        4        5      ...
# 4        13          3           6        4        5      ...
#
#    Yellow Card  Yellow & Red  Red  Man of the Match  1st Goal        Round  \
# ...

# %%
data_fifa2=data_fifa.drop(['Date', 'Team', 'Opponent'], axis=1)
data_fifa2.head()
# Out:
#    Goal Scored  Ball Possession %  Attempts  On-Target  Off-Target  Blocked  \
# 0            5                 40        13          7           3        3
# 1            0                 60         6          0           3        3
# 2            0                 43         8          3           3        2
# 3            1                 57        14          4           6        4
# 4            0                 64        13          3           6        4
#
#    Corners  Offsides  Free Kicks  Saves      ...       Yellow Card  \
# 0        6         3          11      0      ...                 0
# 1        2         1          25      2      ...                 0
# 2        0         1           7      3      ...                 2
# 3        5         1          13      3      ...                 0
# 4        5         0          14      2      ...                 1
#
#    Yellow & Red  Red  Man of the Match  1st Goal        Round  PSO  \
# ...

# %%
data_fifa.Round.unique()
# Out:
# array(['Group Stage', 'Round of 16', 'Quarter Finals', 'Semi- Finals',
#        '3rd Place', 'Final'], dtype=object)

# %%
cleanup_cat =  {"Man of the Match": {"Yes": 1, "No":0},
                "Round": {"Group Stage": 0, "Round of 16": 1, "Quarter Finals": 2, "Semi- Finals": 3,
                                  "3rd Place": 4, "Final": 5 }, "PSO": {"Yes": 1, "No":0}}

data_fifa2.replace(cleanup_cat, inplace=True)

# %%
data_fifa2.dtypes
# Out:
# Goal Scored                 int64
# Ball Possession %           int64
# Attempts                    int64
# On-Target                   int64
# Off-Target                  int64
# Blocked                     int64
# Corners                     int64
# Offsides                    int64
# Free Kicks                  int64
# Saves                       int64
# Pass Accuracy %             int64
# Passes                      int64
# Distance Covered (Kms)      int64
# Fouls Committed             int64
# Yellow Card                 int64
# Yellow & Red                int64
# Red                         int64
# Man of the Match            int64
# 1st Goal                  float64
# Round                       int64
# PSO                         int64
# Goals in PSO                int64
# Own goals                 float64
# Own goal Time             float64
# dtype: object

# %%
from pandas.plotting import parallel_coordinates

plt.figure(figsize = (14, 8))

parallel_coordinates(data_fifa2.drop('Passes', axis=1), 'Man of the Match', color=('#556270','#4ECDC4'), )

plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# #### Naive Bayes

# %%
X, Y= data_fifa2.drop(['Man of the Match', 'Own goals', 'Own goal Time', '1st Goal','Goals in PSO'], axis=1), data_fifa2['Man of the Match']

X.head()
# Out:
#    Goal Scored  Ball Possession %  Attempts  On-Target  Off-Target  Blocked  \
# 0            5                 40        13          7           3        3
# 1            0                 60         6          0           3        3
# 2            0                 43         8          3           3        2
# 3            1                 57        14          4           6        4
# 4            0                 64        13          3           6        4
#
#    Corners  Offsides  Free Kicks  Saves  Pass Accuracy %  Passes  \
# 0        6         3          11      0               78     306
# 1        2         1          25      2               86     511
# 2        0         1           7      3               78     395
# 3        5         1          13      3               86     589
# 4        5         0          14      2               86     433
#
#    Distance Covered (Kms)  Fouls Committed  Yellow Card  Yellow & Red  Red  \
# ...

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics
# Fit a Naive Bayes model to the data
model = GaussianNB()

from sklearn.cross_validation import train_test_split
# Split the data into Trainging and Testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y)

# %%
# Fit the training model
model.fit(X_train,Y_train)
# Out:
# GaussianNB(priors=None)

# %%
# Predicted outcomes
predicted = model.predict(X_test)

# Actual Expected Outvomes
expected = Y_test

print (metrics.accuracy_score(expected, predicted))
# Out:
# 0.375

# %% [markdown]
# The result obtained based on naive bayes is very poor, this might be due to the high dependency between the variables

# %% [markdown]
# #### SVM

# %%
from sklearn.svm import SVC

model_svm = SVC()
model_svm.fit(X_train,Y_train)

predicted = model_svm.predict(X_test)
# Actual Expected Outvomes
expected = Y_test

print (metrics.accuracy_score(expected, predicted))
# Out:
# 0.375

# %%
from sklearn import svm

C = 1.0

rbf_svc = svm.SVC(kernel='rbf',gamma=0.7,C=C).fit(X,Y)

poly_svc = svm.SVC(kernel='poly',degree=3,C=C).fit(X,Y)

predicted_rbf = rbf_svc.predict(X_test)

print (metrics.accuracy_score(expected, predicted_rbf))
# Out:
# 1.0

# %%
predicted_poly = poly_svc.predict(X_test)

print (metrics.accuracy_score(expected, predicted_poly))
# Out:
# 0.875

# %%
from pandas import DataFrame, Series
Data_viz = X
Data_viz['Man of the Match']=Y

# %%
Data_viz.head()
Data_viz.shape
# Out:
# (128, 20)

# %%
sns.pairplot(Data_viz.ix[:,[0,1,2,3,4,5,6,19]], hue='Man of the Match')
# Out:
# C:\Users\stilouche\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
cor_fifa = Data_viz.corr('spearman')
DataFrame(cor_fifa).loc['Man of the Match']
# Out:
# Goal Scored               0.541831
# Ball Possession %         0.121432
# Attempts                  0.190543
# On-Target                 0.263399
# Off-Target                0.143492
# Blocked                   0.016488
# Corners                   0.158710
# Offsides                  0.010646
# Free Kicks                0.114475
# Saves                    -0.012010
# Pass Accuracy %           0.126493
# Passes                    0.116718
# Distance Covered (Kms)    0.039816
# Fouls Committed          -0.118079
# Yellow Card              -0.088684
# Yellow & Red              0.000000
# Red                      -0.125988
# Round                     0.000000
# PSO                       0.000000
# Man of the Match          1.000000
# Name: Man of the Match, dtype: float64

# %% [markdown]
# #### Conclusion

# %% [markdown]
# The SVM with a radial basis function as a kernel gives a very high accuracy around 100%. The explanation based on the correlation shows that 'Man of the Match' is correlated to 'Goal Scored' at a first time.This code is made tot test Github :)
